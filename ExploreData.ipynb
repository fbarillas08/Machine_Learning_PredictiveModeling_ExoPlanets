# %% [markdown]
# ### EXPLORING EXOPLANET DATA

# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import style
style.use('seaborn')

# %%
df = pd.read_csv("data/exoplanet_data.csv")
df = df.dropna(axis='columns', how='all')
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_impact  koi_impact_err1  koi_impact_err2  ...  \
# 0   54.418383   162.513840       0.586            0.059           -0.443  ...
# 1   19.899140   175.850252       0.969            5.126           -0.077  ...
# 2    1.736952   170.307565       1.276            0.115           -0.092  ...
# 3    2.525592   171.595550       0.701            0.235           -0.478  ...
# 4    4.134435   172.979370       0.762            0.139           -0.532  ...
#
# ...

# %%
df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %% [markdown]
# ### Testing koi_disposition against various parameters

# %%
## koi_disposition vs koi_period
boxplot = df.boxplot(column=['koi_period'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_time0bk
boxplot = df.boxplot(column=['koi_time0bk'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_impact
boxplot = df.boxplot(column=['koi_impact'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_duration
boxplot = df.boxplot(column=['koi_duration'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_depth
boxplot = df.boxplot(column=['koi_depth'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_prad
boxplot = df.boxplot(column=['koi_prad'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_teq
boxplot = df.boxplot(column=['koi_teq'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_insol
boxplot = df.boxplot(column=['koi_insol'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_model_snr
boxplot = df.boxplot(column=['koi_model_snr'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_tce_plnt_num
boxplot = df.boxplot(column=['koi_tce_plnt_num'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_steff
boxplot = df.boxplot(column=['koi_steff'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_slogg
boxplot = df.boxplot(column=['koi_slogg'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_srad
boxplot = df.boxplot(column=['koi_srad'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs koi_kepmag
boxplot = df.boxplot(column=['koi_kepmag'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs ra
boxplot = df.boxplot(column=['ra'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
## koi_disposition vs dec
boxplot = df.boxplot(column=['dec'],by='koi_disposition')
# Out:
# C:\Users\Corsair_Barillas\anaconda364\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
### DROP NON-SIGNIFICANT VARIABLES FROM DATASET

# %%
df = df.drop(['koi_insol','koi_steff','koi_slogg','koi_kepmag','ra','dec'], axis=1)

# %%
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  koi_impact_err1  \
# 0                 0   54.418383   162.513840       0.586            0.059
# ...

# %%
df.to_csv(r'C:\Users\Corsair_Barillas\Documents\FAB\Quant\UMBootcamp\UM_Homework\HW21_ML\data\clean_data.csv', index=False, header=True)
